# %% [markdown]
# 1.Multiple students ka data
# 2.Lists
# 3.Dictionaries
# 4.Nested data
# 5.Loops
# 6.Conditions
# 7.Functions
# 8.Average calculation
# 9.Highest/lowest marks
# 10.Attendance analysis
# 11.Performance category
# 12.At-risk student identification
