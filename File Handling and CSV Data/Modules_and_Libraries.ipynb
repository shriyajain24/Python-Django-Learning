# %% [markdown]
# 1. Built-in module

# %%
import math
num = 20
result = math.sqrt(num)
print("Square is :",round(result,2))
# Out:
# Square is : 4.47

# %% [markdown]
# 2. random module

# %%
import random
marks = random.randint(0,100)
print("Marks are :",marks)
# Out:
# Marks are : 25

# %% [markdown]
# 3. from ... import

# %%
from math import sqrt
num = 25
print("Square is :",sqrt(num))
# Out:
# Square is : 5.0
